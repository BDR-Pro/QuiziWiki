# %%
import time

def time_it(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print(f"{func.__name__} took {(end-start)*1000:.2f} ms")
        return result
    return wrapper

# %%
@time_it
def process_question(text, new_text=None, dictionary=False, temp_dict=None):
    lines = text.strip().split('\n')
    question = lines[0]  # The question line
    choices = lines[1:]  # The choice lines
    
    parsed_choices = []
    for choice in choices:
        parts = choice.split('] ')
        label = parts[0][1:]  # Remove '[' for dictionary keys
        value = parts[1].replace("[ANSWER]", "").strip()
        is_answer = "[ANSWER]" in parts[1]
        parsed_choices.append([label, value, is_answer])
    
    # Identify duplicates
    seen = {}
    duplicates = set()
    for _, value, _ in parsed_choices:
        if value in seen:
            duplicates.add(value)
        else:
            seen[value] = True
    
    # Replace the first non-answer duplicate if new_text is provided
    if new_text:
        for value in duplicates:
            for i, (label, choice_value, is_answer) in enumerate(parsed_choices):
                if value == choice_value and not is_answer:
                    parsed_choices[i][1] = new_text
                    break  # Stop after replacing the first non-answer duplicate for this value

    # Construct the new choices text and optionally create a dictionary
    if dictionary:
        # Initialize or use the provided dictionary
        question_dict = temp_dict if temp_dict is not None else {}
        question_dict["question"] = question
        for label, value, is_answer in parsed_choices:
            if is_answer:
                value += " [ANSWER]"
            question_dict[label] = value
        return question_dict
    else:
        new_choices = [f"[{label}] {value}{' [ANSWER]' if is_answer else ''}" for label, value, is_answer in parsed_choices]
        updated_text = question + "\n" + "\n".join(new_choices)
        return updated_text if new_text else (list(duplicates) if duplicates else [])

# %%
# Connect to MongoDB
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Access an environment variable
password = os.getenv('MONGO')

uri = f"mongodb+srv://baderalotaibi3:{password}@cluster0.od393y9.mongodb.net/?retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
db = client["WIKIQUIZ"]
collection = db["WikiQuizEnApi"]
FinalQuestions = db["FinalQuestions"]

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")

except Exception as e:
    print(e)

# %%
@time_it
def removeDublication():
    completed_docs = FinalQuestions.count_documents({})
    All_docs = collection.count_documents({})
    for index,i in enumerate(collection.find().skip(completed_docs)):
        
        percentage_processed = ( index / All_docs) * 100
        print(f"Processed {index+completed_docs} out of {All_docs} documents.")
        print(f"Percentage of documents processed: {percentage_processed:.2f}%")
        question = i['question']
        print("Question")
        print(question)
        response = process_question(question)
        print("Response")
        print(response)
        if not response:
            print("No duplicates found")
            response = process_question(question, dictionary=True, temp_dict=i)
            print(response)
            FinalQuestions.insert_one(i)
        else:
            print("Duplicates found")
            new_question = process_question(question, new_text="None Of The Above", dictionary=True, temp_dict=i)
            print(new_question)
            FinalQuestions.insert_one(new_question)
            

removeDublication()
# Out:
# Processed 319 out of 2436 documents.
# Percentage of documents processed: 0.00%
# Question
# Question: Who left the band in late 2011?
# [A] Matt Warshauer
# [B] Ian O'Neill [ANSWER]
# [C] Matt Reagan
# [D] Patrick Jarrett
# process_question took 0.00 s
# Response
# []
# No duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb453b60456adae102b7f'), 'page_title': '2AM Club', 'summary': '2AM Club is an American band consisting of vocalists Marc E. Bassy and Tyler Cordy, guitarist Matt Reagan, keyboard player Dave Dalton, and bassist \'Sauce\' Matt Warshauer. Ex- drummer Ian O\'Neill left the band in June 2011 for "new opportunities" as a drummer for Gavin Degraw. As of late 2012 Patrick Jarrett, professional drummer, has been touring and playing venues with the band. The band came together in Los Angeles in 2007, after Tyler and Dave who are childhood friends and Marc and Reagan who are also childhood friends met Sauce and later Ian. 2AM Club brings a diverse array of genres, including hip-hop, rock, electro, rap, and alternative. The group was named after their favorite bar, the 2 AM Club in Mill Valley, California. They signed with RCA Records, a division of Sony Music Entertainment in September 2008. The band announced an indefinite hiatus on June 29, 2015.', 'categories': {'Category:2007 establishments in California': 'https://en.wikipedia.org/wiki/Category:2007_establishments_in_California', 'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:All articles with unsourced statements': 'https://en.wikipedia.org/wiki/Category:All_articles_with_unsourced_statements', 'Category:American pop music groups': 'https://en.wikipedia.org/wiki/Category:American_pop_music_groups', 'Category:Articles needing additional references from June 2014': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_June_2014', 'Category:Articles with ISNI identifiers': 'https://en.wikipedia.org/wiki/Category:Articles_with_ISNI_identifiers', 'Category:Articles with MusicBrainz identifiers': 'https://en.wikipedia.org/wiki/Category:Articles_with_MusicBrainz_identifiers', 'Category:Articles with hCards': 'https://en.wikipedia.org/wiki/Category:Articles_with_hCards', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Articles with unsourced statements from May 2023': 'https://en.wikipedia.org/wiki/Category:Articles_with_unsourced_statements_from_May_2023', 'Category:Musical groups disestablished in 2015': 'https://en.wikipedia.org/wiki/Category:Musical_groups_disestablished_in_2015', 'Category:Musical groups established in 2007': 'https://en.wikipedia.org/wiki/Category:Musical_groups_established_in_2007', 'Category:Musical groups from Los Angeles': 'https://en.wikipedia.org/wiki/Category:Musical_groups_from_Los_Angeles', 'Category:Short description is different from Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_is_different_from_Wikidata'}, 'question': 'Question: Who left the band in late 2011?', 'A': 'Matt Warshauer', 'B': "Ian O'Neill [ANSWER]", 'C': 'Matt Reagan', 'D': 'Patrick Jarrett'}
# Processed 320 out of 2436 documents.
# Percentage of documents processed: 0.04%
# Question
# Question: Who ran the competition for gun replacements?
# [A] Garanin
# [B] Kalashnikov [ANSWER]
# [C] Nikitin
# [D] Garanin
# process_question took 0.00 s
# Response
# ['Garanin']
# Duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb464b60456adae102b80'), 'page_title': 'Garanin general-purpose machine guns', 'summary': 'The Garanin machine guns (Пулемёт Гаранина) were a series of general-purpose machine gun prototypes developed by Soviet designer Georgy Semenovich Garanin at OKB-575 in Kovrov. These guns were developed in the context of a contest, started in December 1955, for replacing the company-level RP-46 light machine gun and the battalion-level "heavy" (in the old sense of the term) machine gun SGM with a single new machine gun that could fulfill both roles using different mounts.Garanin\'s first prototype for this competition operated on the principle of lever-delayed blowback. This prototype was rejected in 1957 for failing to meet several of the technical requirements for accuracy and reliability. A later prototype of Garanin relied on gas operation; this one was rejected in 1960, because it was considered inferior to the front-runner designs of Nikitin and Kalashnikov.  Ultimately, Kalashnikov\'s PK machine gun won the competition.', 'categories': {'Category:7.62×54mmR machine guns': 'https://en.wikipedia.org/wiki/Category:7.62%C3%9754mmR_machine_guns', 'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:All stub articles': 'https://en.wikipedia.org/wiki/Category:All_stub_articles', 'Category:Articles needing additional references from December 2012': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_December_2012', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:CS1 Russian-language sources (ru)': 'https://en.wikipedia.org/wiki/Category:CS1_Russian-language_sources_(ru)', 'Category:Delayed blowback firearms': 'https://en.wikipedia.org/wiki/Category:Delayed_blowback_firearms', 'Category:General-purpose machine guns': 'https://en.wikipedia.org/wiki/Category:General-purpose_machine_guns', 'Category:Machine gun stubs': 'https://en.wikipedia.org/wiki/Category:Machine_gun_stubs', 'Category:Machine guns of the Soviet Union': 'https://en.wikipedia.org/wiki/Category:Machine_guns_of_the_Soviet_Union', 'Category:Short description is different from Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_is_different_from_Wikidata', 'Category:Trial and research firearms of the Soviet Union': 'https://en.wikipedia.org/wiki/Category:Trial_and_research_firearms_of_the_Soviet_Union', 'Category:Webarchive template wayback links': 'https://en.wikipedia.org/wiki/Category:Webarchive_template_wayback_links'}, 'question': 'Question: Who ran the competition for gun replacements?', 'A': 'None Of The Above', 'B': 'Kalashnikov [ANSWER]', 'C': 'Nikitin', 'D': 'Garanin'}
# Processed 321 out of 2436 documents.
# Percentage of documents processed: 0.08%
# Question
# Question: Who first ordered the 2BB2 400 class?
# [A] SNCF
# [B] The Paris Orléans Railway
# [C] The Ganz Works [ANSWER]
# [D] Kálmán Kandó
# process_question took 0.00 s
# Response
# []
# No duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb47bb60456adae102b81'), 'page_title': '2BB2 400', 'summary': "The 2BB2 400 class were two electric locomotives built in 1926 for the Paris Orléans (PO) railway of France.After wartime coal shortages during World War I, post-war reconstruction from 1919 focussed on electrification, powered by hydro electricity. In 1923 the PO began electrification of the 200 km section of the Toulouse main line from Paris to Vierzon using a supply of 1,500 V DC. The Ganz Works of Budapest, Hungary supplied these two locomotives, to the design of Kálmán Kandó.The arrangement of the locomotives was unusual for DC locomotives and may have been influenced by Kandó's other designs for AC locomotives, with the large diameter frame-mounted AC motors of the period. The four motors were mounted rigidly on the frames, above the driving wheels. Each motor drove an external jackshaft crank, with the four driving axles coupled in pairs. Drive between the motor jackshafts and the wheels was by coupling rods.  As express passenger locomotives, this also permitted large diameter driving wheels, rather than small-wheeled bogies beneath the frames. Suspension travel between the driven wheels and the fixed motors was achieved through Kandó's triangular linkage design.The coupled wheels, rather than individual traction motors, encouraged resistance to wheelslip. This advantage was recognised and influenced future French designs, such as the typically French monomotor bogie rather than the axle-hung traction motors used elsewhere.In service, the locomotives proved fast and powerful, but were unreliable. When other passenger locomotives became available, they were restricted to freight work at up to 80 kilometres per hour (50 mph). Despite this they were popular with their crews, encouraged by the French practice of attaching crews to the same locomotive. They gained the class nickname, Les Belles Hongroisses. Their later years were spent in freight-only service based at Limoges. They survived into SNCF service until 1938, keeping their original numbers, but were withdrawn and scrapped that year.", 'categories': {'Category:1500 V DC locomotives': 'https://en.wikipedia.org/wiki/Category:1500_V_DC_locomotives', 'Category:2-B-B-2 locomotives': 'https://en.wikipedia.org/wiki/Category:2-B-B-2_locomotives', 'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:Articles needing additional references from December 2015': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_December_2015', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Commons category link from Wikidata': 'https://en.wikipedia.org/wiki/Category:Commons_category_link_from_Wikidata', 'Category:Compagnie du chemin de fer de Paris à Orléans locomotives': 'https://en.wikipedia.org/wiki/Category:Compagnie_du_chemin_de_fer_de_Paris_%C3%A0_Orl%C3%A9ans_locomotives', 'Category:Passenger locomotives': 'https://en.wikipedia.org/wiki/Category:Passenger_locomotives', 'Category:Railway locomotives introduced in 1926': 'https://en.wikipedia.org/wiki/Category:Railway_locomotives_introduced_in_1926', 'Category:Scrapped locomotives': 'https://en.wikipedia.org/wiki/Category:Scrapped_locomotives', 'Category:Short description is different from Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_is_different_from_Wikidata', 'Category:Standard gauge electric locomotives of France': 'https://en.wikipedia.org/wiki/Category:Standard_gauge_electric_locomotives_of_France'}, 'question': 'Question: Who first ordered the 2BB2 400 class?', 'A': 'SNCF', 'B': 'The Paris Orléans Railway', 'C': 'The Ganz Works [ANSWER]', 'D': 'Kálmán Kandó'}
# Processed 322 out of 2436 documents.
# Percentage of documents processed: 0.12%
# Question
# Question: Who owned and operated 2BR?
# [A] Capital Manchester
# [B] Capital
# [C] Global [ANSWER]
# [D] Capital Manchester
# process_question took 0.00 s
# Response
# ['Capital Manchester']
# Duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb488b60456adae102b82'), 'page_title': '2BR', 'summary': 'Two Boroughs Radio (known on air as 2BR) was an Independent Local Radio station serving East and Central Lancashire, England. It was owned and operated by Global and broadcast from studios at Clayton-le-Moors near Accrington.\n2BR was merged with Capital Manchester and relaunched as part of the Capital radio network on 8 April 2019.', 'categories': {'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:Articles needing additional references from May 2017': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_May_2017', 'Category:Articles using infobox radio station': 'https://en.wikipedia.org/wiki/Category:Articles_using_infobox_radio_station', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Defunct radio stations in the United Kingdom': 'https://en.wikipedia.org/wiki/Category:Defunct_radio_stations_in_the_United_Kingdom', 'Category:Mass media in Burnley': 'https://en.wikipedia.org/wiki/Category:Mass_media_in_Burnley', 'Category:Mass media in Hyndburn': 'https://en.wikipedia.org/wiki/Category:Mass_media_in_Hyndburn', 'Category:Mass media in the Borough of Pendle': 'https://en.wikipedia.org/wiki/Category:Mass_media_in_the_Borough_of_Pendle', 'Category:Radio stations disestablished in 2019': 'https://en.wikipedia.org/wiki/Category:Radio_stations_disestablished_in_2019', 'Category:Radio stations established in 2000': 'https://en.wikipedia.org/wiki/Category:Radio_stations_established_in_2000', 'Category:Radio stations in Lancashire': 'https://en.wikipedia.org/wiki/Category:Radio_stations_in_Lancashire', 'Category:Short description is different from Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_is_different_from_Wikidata', 'Category:The Local Radio Company': 'https://en.wikipedia.org/wiki/Category:The_Local_Radio_Company', 'Category:Use British English from August 2012': 'https://en.wikipedia.org/wiki/Category:Use_British_English_from_August_2012', 'Category:Use dmy dates from May 2017': 'https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_May_2017'}, 'question': 'Question: Who owned and operated 2BR?', 'A': 'None Of The Above', 'B': 'Capital', 'C': 'Global [ANSWER]', 'D': 'Capital Manchester'}
# Processed 323 out of 2436 documents.
# Percentage of documents processed: 0.16%
# Question
# Question: What is the title of the film the foreman of a construction crew is involved in?
# [A] new york
# [B] American
# [C] bisexual
# [D] bisexual [ANSWER]
# process_question took 0.00 s
# Response
# ['bisexual']
# Duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb49cb60456adae102b83'), 'page_title': '2by4', 'summary': '2by4 or 2 x 4 (Two by Four) is a 1998 American drama film directed by and starring Jimmy Smallhorne. The screenplay by Smallhorne, Terry McGoff, and Fergus Tighe focuses on the bisexual foreman of a New York City construction crew.\nAt the January 1998 Sundance Film Festival, the film was nominated for the Grand Jury Prize and Declan Quinn won the Cinematography Award. It was released in New York City on November 26, 1999.', 'categories': {'Category:1990s American films': 'https://en.wikipedia.org/wiki/Category:1990s_American_films', 'Category:1990s English-language films': 'https://en.wikipedia.org/wiki/Category:1990s_English-language_films', 'Category:1998 LGBT-related films': 'https://en.wikipedia.org/wiki/Category:1998_LGBT-related_films', 'Category:1998 drama films': 'https://en.wikipedia.org/wiki/Category:1998_drama_films', 'Category:1998 films': 'https://en.wikipedia.org/wiki/Category:1998_films', 'Category:1999 drama films': 'https://en.wikipedia.org/wiki/Category:1999_drama_films', 'Category:1999 films': 'https://en.wikipedia.org/wiki/Category:1999_films', 'Category:1999 independent films': 'https://en.wikipedia.org/wiki/Category:1999_independent_films', 'Category:All Wikipedia articles with plot summary needing attention': 'https://en.wikipedia.org/wiki/Category:All_Wikipedia_articles_with_plot_summary_needing_attention', 'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:American LGBT-related films': 'https://en.wikipedia.org/wiki/Category:American_LGBT-related_films', 'Category:American drama films': 'https://en.wikipedia.org/wiki/Category:American_drama_films', 'Category:American independent films': 'https://en.wikipedia.org/wiki/Category:American_independent_films', 'Category:Articles needing additional references from June 2020': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_June_2020', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:English-language drama films': 'https://en.wikipedia.org/wiki/Category:English-language_drama_films', 'Category:English-language independent films': 'https://en.wikipedia.org/wiki/Category:English-language_independent_films', 'Category:Films set in New York City': 'https://en.wikipedia.org/wiki/Category:Films_set_in_New_York_City', 'Category:Films shot in New York City': 'https://en.wikipedia.org/wiki/Category:Films_shot_in_New_York_City', 'Category:LGBT-related drama films': 'https://en.wikipedia.org/wiki/Category:LGBT-related_drama_films', 'Category:Male bisexuality in film': 'https://en.wikipedia.org/wiki/Category:Male_bisexuality_in_film', 'Category:Short description is different from Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_is_different_from_Wikidata', 'Category:Template film date with 2 release dates': 'https://en.wikipedia.org/wiki/Category:Template_film_date_with_2_release_dates', 'Category:Wikipedia articles with plot summary needing attention from June 2020': 'https://en.wikipedia.org/wiki/Category:Wikipedia_articles_with_plot_summary_needing_attention_from_June_2020'}, 'question': 'Question: What is the title of the film the foreman of a construction crew is involved in?', 'A': 'new york', 'B': 'American', 'C': 'None Of The Above', 'D': 'bisexual [ANSWER]'}
# Processed 324 out of 2436 documents.
# Percentage of documents processed: 0.21%
# Question
# Question: Who first synthesized 2C-G?
# [A] PiHKAL
# [B] Ganesha
# [C] Some medical group
# [D] Alexander Shulgin [ANSWER]
# process_question took 0.00 s
# Response
# []
# No duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb4acb60456adae102b84'), 'page_title': '2C-G', 'summary': '2C-G is a psychedelic phenethylamine of the 2C-series. First synthesized by Alexander Shulgin, it is sometimes used as an entheogen. It has structural and pharmacodynamic properties similar to 2C-D and Ganesha. Like many of the phenethylamines in PiHKAL, 2C-G and its homologs have only been taken by Shulgin and a small test group, making it difficult to ensure completeness when describing effects.', 'categories': {'Category:2C (psychedelics)': 'https://en.wikipedia.org/wiki/Category:2C_(psychedelics)', 'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:Articles containing unverified chemical infoboxes': 'https://en.wikipedia.org/wiki/Category:Articles_containing_unverified_chemical_infoboxes', 'Category:Articles needing additional references from January 2017': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_January_2017', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Articles without KEGG source': 'https://en.wikipedia.org/wiki/Category:Articles_without_KEGG_source', 'Category:Chembox image size set': 'https://en.wikipedia.org/wiki/Category:Chembox_image_size_set', 'Category:Designer drugs': 'https://en.wikipedia.org/wiki/Category:Designer_drugs', 'Category:Short description matches Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_matches_Wikidata'}, 'question': 'Question: Who first synthesized 2C-G?', 'A': 'PiHKAL', 'B': 'Ganesha', 'C': 'Some medical group', 'D': 'Alexander Shulgin [ANSWER]'}
# Processed 325 out of 2436 documents.
# Percentage of documents processed: 0.25%
# Question
# Question: What year was the station's current format changed to 1053 in?
# [A] 1999
# [B] 1986
# [C] 1930
# [D] 1978 [ANSWER]
# process_question took 0.00 s
# Response
# []
# No duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb4c7b60456adae102b85'), 'page_title': '2CA', 'summary': '2CA is an Australian commercial radio station on the AM band serving Canberra. It is jointly owned by the Capital Radio Network and Grant Broadcasters. The station broadcasts on AM Stereo 1053 kHz and on DAB.\n2CA was Canberra\'s first radio station, commencing in 1931 on 1050 kHz, changing to 1053 in 1978. The station plays a variety of hits from the 1960s to the 1980s in its current "Forever Classic" format.', 'categories': {'Category:All Wikipedia articles written in Australian English': 'https://en.wikipedia.org/wiki/Category:All_Wikipedia_articles_written_in_Australian_English', 'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:Articles needing additional references from December 2008': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_December_2008', 'Category:Articles using infobox radio station': 'https://en.wikipedia.org/wiki/Category:Articles_using_infobox_radio_station', 'Category:Articles with Trove identifiers': 'https://en.wikipedia.org/wiki/Category:Articles_with_Trove_identifiers', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Capital Radio Network': 'https://en.wikipedia.org/wiki/Category:Capital_Radio_Network', 'Category:Classic hits radio stations in Australia': 'https://en.wikipedia.org/wiki/Category:Classic_hits_radio_stations_in_Australia', 'Category:Grant Broadcasters': 'https://en.wikipedia.org/wiki/Category:Grant_Broadcasters', 'Category:Official website different in Wikidata and Wikipedia': 'https://en.wikipedia.org/wiki/Category:Official_website_different_in_Wikidata_and_Wikipedia', 'Category:Oldies radio stations in Australia': 'https://en.wikipedia.org/wiki/Category:Oldies_radio_stations_in_Australia', 'Category:Radio stations established in 1931': 'https://en.wikipedia.org/wiki/Category:Radio_stations_established_in_1931', 'Category:Radio stations in Canberra': 'https://en.wikipedia.org/wiki/Category:Radio_stations_in_Canberra', 'Category:Short description matches Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_matches_Wikidata', 'Category:Use Australian English from June 2015': 'https://en.wikipedia.org/wiki/Category:Use_Australian_English_from_June_2015', 'Category:Use dmy dates from June 2015': 'https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_June_2015', 'Category:Webarchive template wayback links': 'https://en.wikipedia.org/wiki/Category:Webarchive_template_wayback_links'}, 'question': "Question: What year was the station's current format changed to 1053 in?", 'A': '1999', 'B': '1986', 'C': '1930', 'D': '1978 [ANSWER]'}
# Processed 326 out of 2436 documents.
# Percentage of documents processed: 0.29%
# Question
# Question: When did 2CH announce the closure of it's business?
# [A] 10 June 2021
# [B] 10 June 2019
# [C] 10 June 2022 [ANSWER]
# [D] 10 June 2022
# process_question took 0.00 s
# Response
# ['10 June 2022']
# Duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb4d9b60456adae102b86'), 'page_title': '2CH', 'summary': '2CH was a commercial radio station in Sydney, Australia, which closed on 10 June 2022, after more than 90 years on the air. It was owned by Pacific Star Network. \nPrior to this, the station changed format on 10 June 2022 to sports, and this was its format at closure.', 'categories': {'Category:1932 establishments in Australia': 'https://en.wikipedia.org/wiki/Category:1932_establishments_in_Australia', 'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:Articles needing additional references from April 2008': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_April_2008', 'Category:Articles using infobox radio station': 'https://en.wikipedia.org/wiki/Category:Articles_using_infobox_radio_station', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Defunct radio stations in Australia': 'https://en.wikipedia.org/wiki/Category:Defunct_radio_stations_in_Australia', 'Category:Easy listening radio stations in Australia': 'https://en.wikipedia.org/wiki/Category:Easy_listening_radio_stations_in_Australia', 'Category:EngvarB from April 2018': 'https://en.wikipedia.org/wiki/Category:EngvarB_from_April_2018', 'Category:Official website different in Wikidata and Wikipedia': 'https://en.wikipedia.org/wiki/Category:Official_website_different_in_Wikidata_and_Wikipedia', 'Category:Oldies radio stations in Australia': 'https://en.wikipedia.org/wiki/Category:Oldies_radio_stations_in_Australia', 'Category:Pacific Star Network': 'https://en.wikipedia.org/wiki/Category:Pacific_Star_Network', 'Category:Radio stations disestablished in 2022': 'https://en.wikipedia.org/wiki/Category:Radio_stations_disestablished_in_2022', 'Category:Radio stations established in 1932': 'https://en.wikipedia.org/wiki/Category:Radio_stations_established_in_1932', 'Category:Radio stations in Sydney': 'https://en.wikipedia.org/wiki/Category:Radio_stations_in_Sydney', 'Category:Short description matches Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_matches_Wikidata', 'Category:Use dmy dates from April 2018': 'https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_April_2018', 'Category:Webarchive template wayback links': 'https://en.wikipedia.org/wiki/Category:Webarchive_template_wayback_links'}, 'question': "Question: When did 2CH announce the closure of it's business?", 'A': '10 June 2021', 'B': '10 June 2019', 'C': '10 June 2022 [ANSWER]', 'D': 'None Of The Above'}
# Processed 327 out of 2436 documents.
# Percentage of documents processed: 0.33%
# Question
# Question: What countries stations do 2CR broadcast in?
# [A] Australia, Sydney and Melbourne
# [B] Australia, New South Wales and New South Wales
# [C] China, Japan, China, Sydney and Melbourne
# [D] Australia, Sydney, Melbourne and Brisbane [ANSWER]
# process_question took 0.00 s
# Response
# []
# No duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb4eeb60456adae102b87'), 'page_title': '2CR China Radio Network', 'summary': "2CR (China Radio Network) is a CB (citizen's band) station that broadcasts Chinese radio programs in the Australian cities of Sydney, Melbourne and Brisbane. It offers a wide range of informative news and radio shows through their proprietary receiver set. It is distinct from the ABC Central West radio station in New South Wales which also uses this call sign.", 'categories': {'Category:1994 establishments in Australia': 'https://en.wikipedia.org/wiki/Category:1994_establishments_in_Australia', 'Category:All Wikipedia articles written in Australian English': 'https://en.wikipedia.org/wiki/Category:All_Wikipedia_articles_written_in_Australian_English', 'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:Articles needing additional references from February 2022': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_February_2022', 'Category:Articles using infobox radio station': 'https://en.wikipedia.org/wiki/Category:Articles_using_infobox_radio_station', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Asian-Australian culture in Melbourne': 'https://en.wikipedia.org/wiki/Category:Asian-Australian_culture_in_Melbourne', 'Category:CS1 maint: numeric names: authors list': 'https://en.wikipedia.org/wiki/Category:CS1_maint:_numeric_names:_authors_list', 'Category:Chinese-Australian culture in Sydney': 'https://en.wikipedia.org/wiki/Category:Chinese-Australian_culture_in_Sydney', 'Category:Ethnic radio stations in Australia': 'https://en.wikipedia.org/wiki/Category:Ethnic_radio_stations_in_Australia', 'Category:Radio stations established in 1994': 'https://en.wikipedia.org/wiki/Category:Radio_stations_established_in_1994', 'Category:Radio stations in Brisbane': 'https://en.wikipedia.org/wiki/Category:Radio_stations_in_Brisbane', 'Category:Radio stations in Melbourne': 'https://en.wikipedia.org/wiki/Category:Radio_stations_in_Melbourne', 'Category:Radio stations in Sydney': 'https://en.wikipedia.org/wiki/Category:Radio_stations_in_Sydney', 'Category:Short description is different from Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_is_different_from_Wikidata', 'Category:Use Australian English from August 2017': 'https://en.wikipedia.org/wiki/Category:Use_Australian_English_from_August_2017', 'Category:Use dmy dates from August 2017': 'https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_August_2017'}, 'question': 'Question: What countries stations do 2CR broadcast in?', 'A': 'Australia, Sydney and Melbourne', 'B': 'Australia, New South Wales and New South Wales', 'C': 'China, Japan, China, Sydney and Melbourne', 'D': 'Australia, Sydney, Melbourne and Brisbane [ANSWER]'}
# Processed 328 out of 2436 documents.
# Percentage of documents processed: 0.37%
# Question
# Question: What year did Muda Aboriginal Corporation receive their full radio licence?
# [A] 1999
# [B] 1996
# [C] 1997
# [D] 2004 [ANSWER]
# process_question took 0.00 s
# Response
# []
# No duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb4fdb60456adae102b88'), 'page_title': '2CUZ', 'summary': '2CUZ FM is an Indigenous community radio station in the North-Western NSW town of Bourke. It has been on air since 1996. The station broadcasts to the regional towns of Brewarrina, Goodooga, Lightning Ridge, Walgett and Weilmoringle . The idea for the development of 2CUZ came from Greg McKellar and other powerful Aboriginal leaders who could see that their community needed more positive portrayals of Aboriginal people.\nIn 1999 Muda Aboriginal Corporation commenced broadcasting and received its full radio licence in 2004. The station now has a full licence and broadcasts 24 hours a day.', 'categories': {'Category:1996 establishments in Australia': 'https://en.wikipedia.org/wiki/Category:1996_establishments_in_Australia', 'Category:All Wikipedia articles written in Australian English': 'https://en.wikipedia.org/wiki/Category:All_Wikipedia_articles_written_in_Australian_English', 'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:Articles needing additional references from April 2010': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_April_2010', 'Category:Articles using infobox radio station': 'https://en.wikipedia.org/wiki/Category:Articles_using_infobox_radio_station', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Bourke, New South Wales': 'https://en.wikipedia.org/wiki/Category:Bourke,_New_South_Wales', 'Category:Community radio stations in Australia': 'https://en.wikipedia.org/wiki/Category:Community_radio_stations_in_Australia', 'Category:Coordinates on Wikidata': 'https://en.wikipedia.org/wiki/Category:Coordinates_on_Wikidata', 'Category:Radio stations established in 1996': 'https://en.wikipedia.org/wiki/Category:Radio_stations_established_in_1996', 'Category:Radio stations in New South Wales': 'https://en.wikipedia.org/wiki/Category:Radio_stations_in_New_South_Wales', 'Category:Short description is different from Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_is_different_from_Wikidata', 'Category:Use Australian English from July 2019': 'https://en.wikipedia.org/wiki/Category:Use_Australian_English_from_July_2019', 'Category:Use dmy dates from July 2019': 'https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_July_2019'}, 'question': 'Question: What year did Muda Aboriginal Corporation receive their full radio licence?', 'A': '1999', 'B': '1996', 'C': '1997', 'D': '2004 [ANSWER]'}
# Processed 329 out of 2436 documents.
# Percentage of documents processed: 0.41%
# Question
# Question: Where did the US Air Force 2d Airborne Command and Control Squadron base?
# [A] Offutt Air Force Base, Nebraska [ANSWER]
# [B] Las Vegas Air Force Base, Nevada
# [C] Ate, Nebraska
# [D] Defiance Air Force Base, North Carolina
# process_question took 0.00 s
# Response
# []
# No duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb513b60456adae102b89'), 'page_title': '2d Airborne Command and Control Squadron', 'summary': "The United States Air Force's 2d Airborne Command and Control Squadron was an airborne command and control unit located at Offutt Air Force Base, Nebraska. The squadron was an integral part of the United States' Post Attack Command and Control System, performing the Operation Looking Glass mission with the Boeing EC-135 aircraft.", 'categories': {'Category:Air control squadrons of the United States Air Force': 'https://en.wikipedia.org/wiki/Category:Air_control_squadrons_of_the_United_States_Air_Force', 'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:All articles with dead external links': 'https://en.wikipedia.org/wiki/Category:All_articles_with_dead_external_links', 'Category:Articles needing additional references from December 2012': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_December_2012', 'Category:Articles with dead external links from November 2018': 'https://en.wikipedia.org/wiki/Category:Articles_with_dead_external_links_from_November_2018', 'Category:Articles with permanently dead external links': 'https://en.wikipedia.org/wiki/Category:Articles_with_permanently_dead_external_links', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Command and control squadrons of the United States Air Force': 'https://en.wikipedia.org/wiki/Category:Command_and_control_squadrons_of_the_United_States_Air_Force', 'Category:Continuity of government in the United States': 'https://en.wikipedia.org/wiki/Category:Continuity_of_government_in_the_United_States', 'Category:Military units and formations established in 1970': 'https://en.wikipedia.org/wiki/Category:Military_units_and_formations_established_in_1970', 'Category:Short description is different from Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_is_different_from_Wikidata', 'Category:United States nuclear command and control': 'https://en.wikipedia.org/wiki/Category:United_States_nuclear_command_and_control', 'Category:Use dmy dates from October 2019': 'https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_October_2019', 'Category:Wikipedia articles incorporating text from the Air Force Historical Research Agency': 'https://en.wikipedia.org/wiki/Category:Wikipedia_articles_incorporating_text_from_the_Air_Force_Historical_Research_Agency'}, 'question': 'Question: Where did the US Air Force 2d Airborne Command and Control Squadron base?', 'A': 'Offutt Air Force Base, Nebraska [ANSWER]', 'B': 'Las Vegas Air Force Base, Nevada', 'C': 'Ate, Nebraska', 'D': 'Defiance Air Force Base, North Carolina'}
# Processed 330 out of 2436 documents.
# Percentage of documents processed: 0.45%
# Question
# Question: What is a more direct representation of a real-world object?
# [A] 3D computer graphics
# [B] Photography
# [C] Photoshop
# [D] 2D computer graphics [ANSWER]
# process_question took 0.00 s
# Response
# []
# No duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb52ab60456adae102b8a'), 'page_title': '2D computer graphics', 'summary': '2D computer graphics is the computer-based generation of digital images—mostly from two-dimensional models (such as 2D geometric models, text, and digital images) and by techniques specific to them. It may refer to the branch of computer science that comprises such techniques or to the models themselves.\n\n2D computer graphics are mainly used in applications that were originally developed upon traditional printing and drawing technologies, such as typography, cartography, technical drawing, advertising, etc.  In those applications, the two-dimensional image is not just a representation of a real-world object, but an independent artifact with added semantic value; two-dimensional models are therefore preferred, because they give more direct control of the image than 3D computer graphics (whose approach is more akin to photography than to typography).\nIn many domains, such as desktop publishing, engineering, and business, a description of a document based on 2D computer graphics techniques can be much smaller than the corresponding digital image—often by a factor of 1/1000 or more.  This representation is also more flexible since it can be rendered at different resolutions to suit different output devices.  For these reasons, documents and illustrations are often stored or transmitted as 2D graphic files.\n2D computer graphics started in the 1950s, based on vector graphics devices. These were largely supplanted by raster-based devices in the following decades. The PostScript language and the X Window System protocol were landmark developments in the field.\n2D graphics models may combine geometric models (also called vector graphics), digital images (also called raster graphics), text to be typeset (defined by content, font style and size, color, position, and orientation), mathematical functions and equations, and more.  These components can be modified and manipulated by two-dimensional geometric transformations such as translation, rotation, and scaling.\nIn object-oriented graphics, the image is described indirectly by an object endowed with a self-rendering method—a procedure that assigns colors to the image pixels by an arbitrary algorithm.  Complex models can be built by combining simpler objects, in the paradigms of object-oriented programming.', 'categories': {'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:All articles that may contain original research': 'https://en.wikipedia.org/wiki/Category:All_articles_that_may_contain_original_research', 'Category:All articles with unsourced statements': 'https://en.wikipedia.org/wiki/Category:All_articles_with_unsourced_statements', 'Category:Articles needing additional references from April 2008': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_April_2008', 'Category:Articles needing additional references from December 2009': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_December_2009', 'Category:Articles that may contain original research from July 2019': 'https://en.wikipedia.org/wiki/Category:Articles_that_may_contain_original_research_from_July_2019', 'Category:Articles with multiple maintenance issues': 'https://en.wikipedia.org/wiki/Category:Articles_with_multiple_maintenance_issues', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Articles with unsourced statements from April 2013': 'https://en.wikipedia.org/wiki/Category:Articles_with_unsourced_statements_from_April_2013', 'Category:CS1 maint: numeric names: authors list': 'https://en.wikipedia.org/wiki/Category:CS1_maint:_numeric_names:_authors_list', 'Category:Commons category link from Wikidata': 'https://en.wikipedia.org/wiki/Category:Commons_category_link_from_Wikidat ...
# Processed 331 out of 2436 documents.
# Percentage of documents processed: 0.49%
# Question
# Question: What is this also referred to as?
# [A] 2D plus Delta [ANSWER]
# [B] 3D image
# [C] HDV+SD
# [D] MSVC
# process_question took 0.00 s
# Response
# []
# No duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb549b60456adae102b8b'), 'page_title': '2D plus Delta', 'summary': '2D Plus Delta (also 2D+Delta) is a method of encoding a 3D image and is listed as a part of MPEG2 and MPEG4 standards, specifically on the H.264 implementation of the Multiview Video Coding extension. This technology originally started as a proprietary method for Stereoscopic Video Coding and content deployment that utilizes the left or right channel as the 2D version and the optimized difference or disparity (Delta) between that image channel view and a second eye image view is injected into the video stream as user data, secondary stream, independent stream, enhancement layer or NALu for deployment. The Delta data can be either a spatial stereo disparity, temporal predictive, bidirectional, or optimized motion compensation.', 'categories': {'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:All articles with style issues': 'https://en.wikipedia.org/wiki/Category:All_articles_with_style_issues', 'Category:All articles with unsourced statements': 'https://en.wikipedia.org/wiki/Category:All_articles_with_unsourced_statements', 'Category:Articles needing additional references from January 2021': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_January_2021', 'Category:Articles with multiple maintenance issues': 'https://en.wikipedia.org/wiki/Category:Articles_with_multiple_maintenance_issues', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Articles with unsourced statements from March 2022': 'https://en.wikipedia.org/wiki/Category:Articles_with_unsourced_statements_from_March_2022', 'Category:Articles with unsourced statements from May 2011': 'https://en.wikipedia.org/wiki/Category:Articles_with_unsourced_statements_from_May_2011', 'Category:Graphics file formats': 'https://en.wikipedia.org/wiki/Category:Graphics_file_formats', 'Category:Short description with empty Wikidata description': 'https://en.wikipedia.org/wiki/Category:Short_description_with_empty_Wikidata_description', 'Category:Stereoscopy': 'https://en.wikipedia.org/wiki/Category:Stereoscopy', 'Category:Wikipedia articles with style issues from July 2015': 'https://en.wikipedia.org/wiki/Category:Wikipedia_articles_with_style_issues_from_July_2015'}, 'question': 'Question: What is this also referred to as?', 'A': '2D plus Delta [ANSWER]', 'B': '3D image', 'C': 'HDV+SD', 'D': 'MSVC'}
# Processed 332 out of 2436 documents.
# Percentage of documents processed: 0.53%
# Question
# Question: Who owns 2EARfm?
# [A] A community organisation.
# [B] A radio station
# [C] CBAA
# [D] EAR Inc [ANSWER]
# process_question took 0.00 s
# Response
# []
# No duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb574b60456adae102b8c'), 'page_title': '2EARfm', 'summary': '2EARfm is a community radio station, based in Moruya, on the Far South Coast of New South Wales, Australia.\nEAR, an acronym for "Eurobodalla Access Radio", is located in the Eurobodalla Shire and has been broadcasting on frequencies 107.5 and 102.9 MHz for more than 30 years.\nThe station’s broadcasters, presenters and all other staff are volunteers. \nFunds to operate the station are generated through sponsorship, fund raising events, donations and annual membership subscriptions.\n2EARfm is owned and operated by EAR Inc, a not for profit community organisation.\nThe organisation is controlled by an annually elected Management Committee and all volunteers must be members of EAR Inc. Membership is open to anybody who lives in or works in the Eurobodalla Shire or has an interest in promoting the region through community radio. The station is a member of the Community Broadcasting Association of Australia (CBAA).', 'categories': {'Category:All Wikipedia articles written in Australian English': 'https://en.wikipedia.org/wiki/Category:All_Wikipedia_articles_written_in_Australian_English', 'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:All stub articles': 'https://en.wikipedia.org/wiki/Category:All_stub_articles', 'Category:Articles needing additional references from October 2014': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_October_2014', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Australian radio station stubs': 'https://en.wikipedia.org/wiki/Category:Australian_radio_station_stubs', 'Category:Community radio stations in Australia': 'https://en.wikipedia.org/wiki/Category:Community_radio_stations_in_Australia', 'Category:Coordinates on Wikidata': 'https://en.wikipedia.org/wiki/Category:Coordinates_on_Wikidata', 'Category:Radio stations in New South Wales': 'https://en.wikipedia.org/wiki/Category:Radio_stations_in_New_South_Wales', 'Category:Short description is different from Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_is_different_from_Wikidata', 'Category:Use Australian English from July 2019': 'https://en.wikipedia.org/wiki/Category:Use_Australian_English_from_July_2019', 'Category:Use dmy dates from July 2019': 'https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_July_2019'}, 'question': 'Question: Who owns 2EARfm?', 'A': 'A community organisation.', 'B': 'A radio station', 'C': 'CBAA', 'D': 'EAR Inc [ANSWER]'}
# Processed 333 out of 2436 documents.
# Percentage of documents processed: 0.57%
# Question
# Question: When was 2nd Season released?
# [A] February 20, 2008
# [B] January 30, 2009
# [C] January 2, 2008
# [D] September 30, 2008 [ANSWER]
# process_question took 0.00 s
# Response
# []
# No duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65beb77ab60456adae102b8f'), 'page_title': '2econd Season', 'summary': "2econd Season is the second studio album by Atlanta-based American rapper Unk. It was released on September 30, 2008 through Koch Records. Production was handled by DJ Montay, Mr. Jonz, MC Assault and Malcolm X. It features guest appearances from Blazed, 11 Dub, D'Angel, Loko, Manish Man, Princess, Project Pat, Ray J, Sandman, Sean Kingston, Stuey Rock, Three 6 Mafia and Ying Yang Twins. The album peaked at number 104 on the Billboard 200, number 15 on the Top R&B/Hip-Hop Albums, number 6 on the Top Rap Albums, and topped the Heatseekers Albums charts in the United States.", 'categories': {'Category:2008 albums': 'https://en.wikipedia.org/wiki/Category:2008_albums', 'Category:Album articles lacking alt text for covers': 'https://en.wikipedia.org/wiki/Category:Album_articles_lacking_alt_text_for_covers', 'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:Articles needing additional references from April 2023': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_April_2023', 'Category:Articles with hAudio microformats': 'https://en.wikipedia.org/wiki/Category:Articles_with_hAudio_microformats', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:E1 Music albums': 'https://en.wikipedia.org/wiki/Category:E1_Music_albums', 'Category:MNRK Music Group albums': 'https://en.wikipedia.org/wiki/Category:MNRK_Music_Group_albums', 'Category:Short description is different from Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_is_different_from_Wikidata', 'Category:Unk albums': 'https://en.wikipedia.org/wiki/Category:Unk_albums'}, 'question': 'Question: When was 2nd Season released?', 'A': 'February 20, 2008', 'B': 'January 30, 2009', 'C': 'January 2, 2008', 'D': 'September 30, 2008 [ANSWER]'}
# Processed 334 out of 2436 documents.
# Percentage of documents processed: 0.62%
# Question
# Question: Which Australian network is 2EL a relay of?
# [A] 2SM [ANSWER]
# [B] 2GZ
# [C] 2GZ
# [D] 2GZ
# process_question took 0.00 s
# Response
# ['2GZ']
# Duplicates found
# process_question took 0.00 s
# ...
# No duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65bec67db60456adae102c1b'), 'page_title': 'A329(M) motorway', 'summary': 'The A329(M) is a motorway in Berkshire, England. It is 4 miles (6.4 km) long and runs from the west of Bracknell to the north west of Winnersh. It is one of a small number of parts of the motorway system in England that are managed by the local highway authority, in this case Wokingham Borough Council, rather than National Highways.', 'categories': {'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:All pages needing cleanup': 'https://en.wikipedia.org/wiki/Category:All_pages_needing_cleanup', 'Category:Articles needing additional references from February 2009': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_February_2009', 'Category:Articles using KML from Wikidata': 'https://en.wikipedia.org/wiki/Category:Articles_using_KML_from_Wikidata', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:CS1 maint: location missing publisher': 'https://en.wikipedia.org/wiki/Category:CS1_maint:_location_missing_publisher', 'Category:Infobox road instances in the United Kingdom': 'https://en.wikipedia.org/wiki/Category:Infobox_road_instances_in_the_United_Kingdom', 'Category:Infobox road maps tracking category': 'https://en.wikipedia.org/wiki/Category:Infobox_road_maps_tracking_category', 'Category:Motorways in England': 'https://en.wikipedia.org/wiki/Category:Motorways_in_England', 'Category:Roads in Berkshire': 'https://en.wikipedia.org/wiki/Category:Roads_in_Berkshire', 'Category:Short description matches Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_matches_Wikidata', 'Category:Use British English from May 2014': 'https://en.wikipedia.org/wiki/Category:Use_British_English_from_May_2014', 'Category:Use dmy dates from May 2014': 'https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_May_2014', 'Category:Wikipedia articles needing a junction list from December 2021': 'https://en.wikipedia.org/wiki/Category:Wikipedia_articles_needing_a_junction_list_from_December_2021'}, 'question': 'Question: Which council manages the motorway system in England?', 'A': 'National Highways', 'B': 'Bracknell', 'C': 'Wokingham Borough Council [ANSWER]', 'D': 'The Government'}
# Processed 474 out of 2436 documents.
# Percentage of documents processed: 6.36%
# Question
# Question: Who is known for the busiest section of the road?
# [A] Traffic for the Royal Cornwall Hospital, Truro College and the Richard Lander School
# [B] Truro Road between Truro City Centre and Chiverton Cross [ANSWER]
# [C] Traffic from Truro College heading into Truro
# [D] Traffic from Truro College heading into Truro
# process_question took 0.00 s
# Response
# ['Traffic from Truro College heading into Truro']
# Duplicates found
# process_question took 0.00 s
# {'_id': ObjectId('65bec6a4b60456adae102c1c'), 'page_title': 'A390 road', 'summary': 'The A390 is a road in Cornwall and Devon, England. It runs from Tavistock to 5 miles (8.0 km) north west of the city of Truro. Starting in Tavistock, it heads south-westwards towards Liskeard, crossing over the River Tamar and into Cornwall, then through Gunnislake and Callington. Immediately before Liskeard, it merges with the A38 north of the town. It diverges from the A38 at Dobwalls, where it then runs in a south-westerly direction to Truro via Lostwithiel, St. Blazey, and St Austell. It then forms an upside down elongated square loop, and bypasses Truro City Centre. It then heads north west out of the city, where it forms the main corridor into Truro from the west. It passes the Royal Cornwall Hospital and skirts the village of Threemilestone, before linking up with the A30 road at Chiverton Cross, where the A390 terminates. Chiverton Cross is where the A390 trunk road from Truro and the B3277 to St Agnes meet the east–west A30 trunk road. Before the A390 was rerouted away from Chacewater it ended at its junction with the A30 at Scorrier.It forms part of the main route (the Truro to Dobwalls section) from Truro to Plymouth, although after a severe accident in Lostwithiel in 1999 heavy goods vehicles are diverted from it at the top of Edgcumbe Road, Lostwithiel.\nBy far the busiest section of the road is known as Truro Road between Truro City Centre and Chiverton Cross, where it carries through traffic to West Cornwall, as well as commuting traffic to and from Truro, and traffic for the Royal Cornwall Hospital, Truro College and the Richard Lander School. There are many residential new housing estates in this area which have created further traffic. The section from Truro College heading into Truro from the west also includes a Bus lane and some dual carriageway sections.', 'categories': {'Category:All articles needing additional references': 'https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references', 'Category:Articles needing additional references from September 2012': 'https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_September_2012', 'Category:Articles with Geo': 'https://en.wikipedia.org/wiki/Category:Articles_with_Geo', 'Category:Articles with short description': 'https://en.wikipedia.org/wiki/Category:Articles_with_short_description', 'Category:Commons category link from Wikidata': 'https://en.wikipedia.org/wiki/Category:Commons_category_link_from_Wikidata', 'Category:Coordinates on Wikidata': 'https://en.wikipedia.org/wiki/Category:Coordinates_on_Wikidata', 'Category:Geographic coordinate lists': 'https://en.wikipedia.org/wiki/Category:Geographic_coordinate_lists', 'Category:Infobox road instances in the United Kingdom': 'https://en.wikipedia.org/wiki/Category:Infobox_road_instances_in_the_United_Kingdom', 'Category:Infobox road maps tracking category': 'https://en.wikipedia.org/wiki/Category:Infobox_road_maps_tracking_category', 'Category:Lists of coordinates': 'https://en.wikipedia.org/wiki/Category:Lists_of_coordinates', 'Category:Roads in Cornwall': 'https://en.wikipedia.org/wiki/Category:Roads_in_Cornwall', 'Category:Roads in England': 'https://en.wikipedia.org/wiki/Category:Roads_in_England', 'Category:Short description matches Wikidata': 'https://en.wikipedia.org/wiki/Category:Short_description_matches_Wikidata', 'Category:Transport in Devon': 'https://en.wikipedia.org/wiki/Category:Transport_in_Devon', 'Category:Truro': 'https://en.wikipedia.org/wiki/Category:Truro', 'Category:Use British English from February 2013': 'https://en.wikipedia.org/wiki/Category:Use_British_English_from_February_2013', 'Category:Use dmy dates from June 2023': 'https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_June_2023'}, 'question': 'Question: Who is known for the busiest section of the road?', 'A': 'Traffic for the Royal Cornwall Hospital, Truro College and the Richard Lander Sch ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 28
#      24             print(new_question)
#      25             FinalQuestions.insert_one(new_question)
# ---> 28 removeDublication()
#
# Cell In[13], line 6, in time_it.<locals>.wrapper(*args, **kwargs)
#       4 def wrapper(*args, **kwargs):
#       5     start = time.time()
# ----> 6     result = func(*args, **kwargs)
#       7     end = time.time()
#       8     print(f"{func.__name__} took {(end-start):.2f} s")
#
# Cell In[17], line 25, in removeDublication()
#      23 new_question = process_question(question, new_text="None Of The Above", dictionary=True, temp_dict=i)
#      24 print(new_question)
# ---> 25 FinalQuestions.insert_one(new_question)
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\collection.py:671, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     667     document["_id"] = ObjectId()  # type: ignore[index]
#     669 write_concern = self._write_concern_for(session)
#     670 return InsertOneResult(
# --> 671     self._insert_one(
#     672         document,
#     673         ordered=True,
#     674         write_concern=write_concern,
#     675         op_id=None,
#     676         bypass_doc_val=bypass_document_validation,
#     677         session=session,
#     678         comment=comment,
#     679     ),
#     680     write_concern.acknowledged,
#     681 )
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\collection.py:611, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     599     result = conn.command(
#     600         self.__database.name,
#     601         command,
#    (...)
#     606         retryable_write=retryable_write,
#     607     )
#     609     _check_write_command_response(result)
# --> 611 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     613 if not isinstance(doc, RawBSONDocument):
#     614     return doc.get("_id")
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1568, in MongoClient._retryable_write(self, retryable, func, session)
#    1566 """Internal retryable write helper."""
#    1567 with self._tmp_session(session) as s:
# -> 1568     return self._retry_with_session(retryable, func, s, None)
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1413, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1403 """Execute an operation with at most one consecutive retries
#    1404
#    1405 Returns func()'s return value on success. On error retries the same
#    (...)
#    1408 Re-raises any exception thrown by func().
#    1409 """
#    1410 retryable = bool(
#    1411     retryable and self.options.retry_writes and session and not session.in_transaction
#    1412 )
# -> 1413 return self._retry_internal(retryable, func, session, bulk)
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1460, in MongoClient._retry_internal(self, retryable, func, session, bulk)
#    1458                 raise last_error
#    1459             retryable = False
# -> 1460         return func(session, conn, retryable)
#    1461 except ServerSelectionTimeoutError:
#    1462     if is_retrying():
#    1463         # The application may think the write was never attempted
#    1464         # if we raise ServerSelectionTimeoutError on the retry
#    1465         # attempt. Raise the original exception instead.
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\collection.py:599, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     596 if bypass_doc_val:
#     597     command["bypassDocumentValidation"] = True
# --> 599 result = conn.command(
#     600     self.__database.name,
#     601     command,
#     602     write_concern=write_concern,
#     603     codec_options=self.__write_response_codec_options,
#     604     session=session,
#     605     client=self.__database.client,
#     606     retryable_write=retryable_write,
#     607 )
#     609 _check_write_command_response(result)
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:315, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     312 from pymongo.pool import Connection
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except OperationFailure as exc:
#     317     if no_reauth:
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:960, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     958 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     959 except BaseException as error:
# --> 960     self._raise_connection_failure(error)
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:932, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     930     self._raise_if_not_writable(unacknowledged)
#     931 try:
# --> 932     return command(
#     933         self,
#     934         dbname,
#     935         spec,
#     936         self.is_mongos,
#     937         read_preference,
#     938         codec_options,
#     939         session,
#     940         client,
#     941         check,
#     942         allowable_errors,
#     943         self.address,
#     944         listeners,
#     945         self.max_bson_size,
#     946         read_concern,
#     947         parse_write_concern_error=parse_write_concern_error,
#     948         collation=collation,
#     949         compression_ctx=self.compression_context,
#     950         use_op_msg=self.op_msg_enabled,
#     951         unacknowledged=unacknowledged,
#     952         user_fields=user_fields,
#     953         exhaust_allowed=exhaust_allowed,
#     954         write_concern=write_concern,
#     955     )
#     956 except (OperationFailure, NotPrimaryError):
#     957     raise
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:181, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     179     response_doc: _DocumentOut = {"ok": 1}
#     180 else:
# --> 181     reply = receive_message(conn, request_id)
#     182     conn.more_to_come = reply.more_to_come
#     183     unpacked_docs = reply.unpack_response(
#     184         codec_options=codec_options, user_fields=user_fields
#     185     )
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:247, in receive_message(conn, request_id, max_message_size)
#     245         deadline = None
#     246 # Ignore the response's request id.
# --> 247 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     248 # No request_id for exhaust cursor "getMore".
#     249 if request_id is not None:
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:328, in _receive_data_on_socket(conn, length, deadline)
#     326     if _csot.get_timeout() and deadline is not None:
#     327         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 328     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     329 except BLOCKING_IO_ERRORS:
#     330     raise socket.timeout("timed out")
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1249, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1245     if flags != 0:
#    1246         raise ValueError(
#    1247           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1248           self.__class__)
# -> 1249     return self.read(nbytes, buffer)
#    1250 else:
#    1251     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\bdrkh\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:
